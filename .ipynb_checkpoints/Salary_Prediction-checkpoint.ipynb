# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Downloads/Salary_Data_Based_country_and_race.csv')
print(df)
# Out:
#       Unnamed: 0   Age  Gender    Education Level              Job Title  \
# 0              0  32.0    Male         Bachelor's      Software Engineer
# 1              1  28.0  Female           Master's           Data Analyst
# 2              2  45.0    Male                PhD         Senior Manager
# 3              3  36.0  Female         Bachelor's        Sales Associate
# 4              4  52.0    Male           Master's               Director
# ...          ...   ...     ...                ...                    ...
# 6699        6699  49.0  Female                PhD  Director of Marketing
# 6700        6700  32.0    Male        High School        Sales Associate
# 6701        6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702        6702  46.0    Male    Master's Degree      Marketing Manager
# 6703        6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary    Country        Race
# ...

# %%
df.describe(include= 'all')
# Out:
#          Unnamed: 0          Age Gender    Education Level          Job Title  \
# count   6704.000000  6702.000000   6702               6701               6702
# unique          NaN          NaN      3                  7                193
# top             NaN          NaN   Male  Bachelor's Degree  Software Engineer
# freq            NaN          NaN   3674               2267                518
# mean    3351.500000    33.620859    NaN                NaN                NaN
# std     1935.422435     7.614633    NaN                NaN                NaN
# min        0.000000    21.000000    NaN                NaN                NaN
# 25%     1675.750000    28.000000    NaN                NaN                NaN
# 50%     3351.500000    32.000000    NaN                NaN                NaN
# 75%     5027.250000    38.000000    NaN                NaN                NaN
# max     6703.000000    62.000000    NaN                NaN                NaN
#
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0   Age  Gender Education Level              Job Title  \
# 0           0  32.0    Male      Bachelor's      Software Engineer
# 1           1  28.0  Female        Master's           Data Analyst
# 2           2  45.0    Male             PhD         Senior Manager
# 3           3  36.0  Female      Bachelor's        Sales Associate
# 4           4  52.0    Male        Master's               Director
# 5           5  29.0    Male      Bachelor's      Marketing Analyst
# 6           6  42.0  Female        Master's        Product Manager
# 7           7  31.0    Male      Bachelor's          Sales Manager
# 8           8  26.0  Female      Bachelor's  Marketing Coordinator
# 9           9  38.0    Male             PhD       Senior Scientist
#
#    Years of Experience    Salary    Country        Race
# 0                  5.0   90000.0         UK       White
# 1                  3.0   65000.0        USA    Hispanic
# 2                 15.0  150000.0     Canada       White
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# Country                0
# Race                   0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6704 entries, 0 to 6703
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           6704 non-null   int64
#  1   Age                  6702 non-null   float64
#  2   Gender               6702 non-null   object
#  3   Education Level      6701 non-null   object
#  4   Job Title            6702 non-null   object
#  5   Years of Experience  6701 non-null   float64
#  6   Salary               6699 non-null   float64
#  7   Country              6704 non-null   object
#  8   Race                 6704 non-null   object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 471.5+ KB

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# Country                0
# Race                   0
# dtype: int64

# %%
df['Education Level'].unique()
# Out:
# array(["Bachelor's", "Master's", 'PhD', "Bachelor's Degree",
#        "Master's Degree", 'High School', 'phD'], dtype=object)

# %%
df['Education Level']=df["Education Level"].str.replace("Master's Degree","Master's")
df['Education Level']=df["Education Level"].str.replace("Bachelor's Degree","Bachelor's")
df['Education Level']=df["Education Level"].str.replace("phD","PhD")

# %%
df['Education Level'].unique()
# Out:
# array(["Bachelor's", "Master's", 'PhD', 'High School'], dtype=object)

# %%
df['Job Title'].unique()
# Out:
# array(['Software Engineer', 'Data Analyst', 'Senior Manager',
#        'Sales Associate', 'Director', 'Marketing Analyst',
#        'Product Manager', 'Sales Manager', 'Marketing Coordinator',
#        'Senior Scientist', 'Software Developer', 'HR Manager',
#        'Financial Analyst', 'Project Manager', 'Customer Service Rep',
#        'Operations Manager', 'Marketing Manager', 'Senior Engineer',
#        'Data Entry Clerk', 'Sales Director', 'Business Analyst',
#        'VP of Operations', 'IT Support', 'Recruiter', 'Financial Manager',
#        'Social Media Specialist', 'Software Manager', 'Junior Developer',
#        'Senior Consultant', 'Product Designer', 'CEO', 'Accountant',
#        'Data Scientist', 'Marketing Specialist', 'Technical Writer',
#        'HR Generalist', 'Project Engineer', 'Customer Success Rep',
#        'Sales Executive', 'UX Designer', 'Operations Director',
#        'Network Engineer', 'Administrative Assistant',
# ...

# %%
df['Country'].unique()
# Out:
# array(['UK', 'USA', 'Canada', 'China', 'Australia'], dtype=object)

# %%
df['Country'].value_counts()
# Out:
# USA          1359
# China        1343
# Australia    1336
# UK           1335
# Canada       1325
# Name: Country, dtype: int64

# %%
wise=df['Country'].value_counts().reset_index()

wise.columns=['Country','Number']
print(wise)
# Out:
#      Country  Number
# 0        USA    1359
# 1      China    1343
# 2  Australia    1336
# 3         UK    1335
# 4     Canada    1325

# %%
#salary with country
x=df["Country"]
y=df["Salary"]
plt.bar(x,y)
plt.show()

# %%
import seaborn as sns
sns.histplot(df['Country'], bins=30, kde= True,color='red')
# Out:
# <Axes: xlabel='Country', ylabel='Count'>

# %%
plt.figure(figsize=(20,5))
sns.histplot(df['Race'],bins=50,kde= True,color='Blue')
plt.grid(True)

# %%
plt.figure(figsize=(20,5))
sns.histplot(df['Gender'],bins=50,kde= True,color='Blue')
plt.grid(True)

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', 'Other'], dtype=object)

# %%
df['Job Title'].unique()
plt.figure(figsize=(10,10))
sns.histplot(df['Job Title'],bins=50,kde= True,color='Yellow')
plt.grid(True)

# %%
plt.figure(figsize=(20, 15))
sns.boxplot(data=df, x='Race', y='Salary')
plt.title('Salary Distribution by Race')
# Out:
# Text(0.5, 1.0, 'Salary Distribution by Race')

# %%
plt.figure(figsize=(20, 15))
x=df["Race"]
y=df["Salary"]
plt.bar(x,y,color='orange')
plt.title('Salary distribution by Race')
plt.xlabel('Race')
plt.ylabel('Salary')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20, 15))
x=df["Country"]
y=df["Salary"]
plt.bar(x,y,color='darkred')
plt.title('Salary distribution by Country')
plt.xlabel('Country')
plt.ylabel('Salary')
plt.grid(True)
plt.show()

# %%
sns.barplot(data=df, x='Education Level', y='Salary')
plt.title('Salary Distribution by Education Level')
# Out:
# Text(0.5, 1.0, 'Salary Distribution by Education Level')

# %%
sns.barplot(data=df, x='Gender', y='Salary')
plt.title('Salary Distribution by Gender')
# Out:
# Text(0.5, 1.0, 'Salary Distribution by Gender')

# %%
plt.figure(figsize=(20, 15))

sns.scatterplot(data=df, x='Age', y='Salary')
plt.title('Salary Correlation to Age')
# Out:
# Text(0.5, 1.0, 'Salary Correlation to Age')

# %%
plt.figure(figsize=(20, 15))

sns.barplot(data=df, x='Age', y='Salary')
plt.title('Salary Correlation to Age')
# Out:
# Text(0.5, 1.0, 'Salary Correlation to Age')

# %%
sns.scatterplot(data=df, x='Years of Experience', y='Salary')
plt.title('Salary Correlation to Years of Experience')
# Out:
# Text(0.5, 1.0, 'Salary Correlation to Years of Experience')

# %%
counts=df['Job Title'].value_counts().nlargest(10)

counts.columns=['title','Number']
print(counts)
# Out:
# Software Engineer            518
# Data Scientist               453
# Software Engineer Manager    376
# Data Analyst                 363
# Senior Project Engineer      318
# Product Manager              313
# Full Stack Engineer          308
# Marketing Manager            255
# Back end Developer           244
# Senior Software Engineer     244
# Name: Job Title, dtype: int64

# %%
Software=df[df['Job Title']=='Software Engineer']
Software.head()
# Out:
#      Unnamed: 0   Age  Gender Education Level          Job Title  \
# 0             0  32.0    Male      Bachelor's  Software Engineer
# 376         376  28.0  Female      Bachelor's  Software Engineer
# 380         380  29.0  Female      Bachelor's  Software Engineer
# 384         384  31.0  Female      Bachelor's  Software Engineer
# 388         388  29.0  Female      Bachelor's  Software Engineer
#
#      Years of Experience    Salary    Country      Race
# 0                    5.0   90000.0         UK     White
# 376                  3.0  125000.0     Canada     Black
# 380                  4.0  140000.0  Australia     White
# 384                  6.0  155000.0         UK     Welsh
# 388                  4.0  140000.0        USA  Hispanic

# %%
Software.describe()
# Out:
#         Unnamed: 0         Age  Years of Experience         Salary
# count   518.000000  518.000000           518.000000     518.000000
# mean   2514.299228   28.318533             4.449807  113243.243243
# std    1837.399506    2.617617             2.219221   48031.287179
# min       0.000000   22.000000             1.000000   50000.000000
# 25%     845.750000   27.000000             3.000000   70000.000000
# 50%    2329.500000   28.000000             4.000000   90000.000000
# 75%    3787.250000   30.000000             5.000000  160000.000000
# max    6247.000000   42.000000            13.000000  197000.000000

# %%
sns.scatterplot(data=Software, x='Years of Experience', y='Salary')
plt.title('Salary Correlation to Years of Experience')
# Out:
# Text(0.5, 1.0, 'Salary Correlation to Years of Experience')

# %%
sns.barplot(data=Software, x='Education Level', y='Salary')
plt.title('Salary Correlation to education')
# Out:
# Text(0.5, 1.0, 'Salary Correlation to education')

# %%
sns.barplot(data=Software, x='Gender', y='Salary')
plt.title('Salary Correlation to gender')
# Out:
# Text(0.5, 1.0, 'Salary Correlation to gender')

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_predict
from sklearn.preprocessing import StandardScaler


from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import mean_squared_error, r2_score

data_metrics = df[['Age','Years of Experience','Salary']]
column_metrics = data_metrics.columns

scaler = StandardScaler()
scaler.fit(data_metrics)
df_metrics_scaled = pd.DataFrame(scaler.transform(data_metrics), columns=column_metrics)

from sklearn.model_selection import train_test_split
x = df_metrics_scaled[['Age','Years of Experience']]
y = df_metrics_scaled['Salary']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, random_state=3, train_size = 0.7)

# %%
print("Training set: {} and Test set: {}".format(X_train.shape, X_test.shape))
# Out:
# Training set: (4688, 2) and Test set: (2010, 2)

# %%
from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression()
linear_regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# Predicting results
y_pred_lr= linear_regressor.predict(X_test)
y_pred_lr
# Out:
# array([-0.82636327, -0.85731115, -0.7644675 , ..., -0.3519713 ,
#         0.98853467,  0.18078296])

# %%
# Linear Regression - Model Evaluation
import numpy as np

from sklearn.metrics import mean_absolute_error as mae, mean_squared_error as mse, accuracy_score
print("---- Linear Regression - Model Evaluation ----")
print("Mean Absolute Error (MAE): {}".format(mae(y_test, y_pred_lr)))
print("Mean Squared Error (MSE): {}".format(mse(y_test, y_pred_lr)))
print("Root Mean Squared Error (RMSE): {}".format(np.sqrt(mse(y_test, y_pred_lr))))
# Out:
# ---- Linear Regression - Model Evaluation ----
# Mean Absolute Error (MAE): 0.4611024143205381
# Mean Squared Error (MSE): 0.3314960732696354
# Root Mean Squared Error (RMSE): 0.575756956770507

# %%
dfr=pd.DataFrame({'Actual':y_test,'Predicted': y_pred_lr})
dfr.reset_index(drop=True, inplace=True)
dfr.head(10)
# Out:
#      Actual  Predicted
# 0 -0.858739  -0.826363
# 1 -1.502851  -0.857311
# 2 -0.100960  -0.764467
# 3  1.566154   0.503969
# 4  1.414598   0.885517
# 5 -1.188145  -1.039465
# 6  0.467374  -0.551366
# 7  1.509320   0.988535
# 8  0.073784   0.916465
# 9 -0.858739  -0.551366

# %%
r2_score(y_test,y_pred_lr)*100
# Out:
# 67.25651473499153

# %%
print("Accuracy of linear regreesion on training set: {:.2f}".format(linear_regressor.score(X_train, y_train)))
print("Accuracy of linear regression on test set:{:.2f}" .format(linear_regressor.score(X_test, y_test)))
# Out:
# Accuracy of linear regreesion on training set: 0.66
# Accuracy of linear regression on test set:0.67

# %%
# plot the graph between y_predict and y_test
sns.scatterplot(x=y_test, y=y_pred_lr)
plt.xlabel('Actual Salary')
plt.ylabel('Predicted Salary')
plt.title('Actual vs Predict Salary')

plt.show()

# %%
# Decision Tree Regression Model
from sklearn.tree import DecisionTreeRegressor
decision_regressor = DecisionTreeRegressor()
decision_regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
# Predicting results
y_pred_dt = decision_regressor.predict(X_test)
y_pred_dt
# Out:
# array([-1.05850274, -1.27625996, -0.5419846 , ...,  0.47348419,
#         1.5093201 ,  0.25209616])

# %%
# Decision Tree Regression - Model Evaluation
print("---- Decision Tree Regression - Model Evaluation ----")
print("Mean Absolute Error (MAE): {}".format(mae(y_test, y_pred_dt)))
print("Mean Squared Error (MSE): {}".format(mse(y_test, y_pred_dt)))
print("Root Mean Squared Error (RMSE): {}".format(np.sqrt(mse(y_test, y_pred_dt))))
# Out:
# ---- Decision Tree Regression - Model Evaluation ----
# Mean Absolute Error (MAE): 0.2829119547343162
# Mean Squared Error (MSE): 0.15876471015825258
# Root Mean Squared Error (RMSE): 0.3984528957834948

# %%
print("Accuracy of Decision Tree classifier on training set: {:.2f}".format(decision_regressor.score(X_train, y_train)))
print("Accuracy of Decision Tree classifier on test set:{:.2f}" .format(decision_regressor.score(X_test, y_test)))
# Out:
# Accuracy of Decision Tree classifier on training set: 0.85
# Accuracy of Decision Tree classifier on test set:0.84
